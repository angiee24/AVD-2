# %% [markdown]
# <a href="https://colab.research.google.com/github/angiee24/AVD-2/blob/main/AVD_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #DATA UNDERSTANDING

# %%
csv_path = "/content/drive/MyDrive/AVD/updated_version.csv"
df = pd.read_csv(csv_path)

df.head()
# Out:
#    age  sex  total_cholesterol         ldl        hdl  systolic_bp  \
# 0   57    1         229.463642  175.879129  39.225687   124.070127
# 1   58    1         186.464120  128.984916  34.950968    95.492552
# 2   37    1         251.300719  152.347592  45.913288    99.519335
# 3   55    1         192.058908  116.803684  67.208925   122.460002
# 4   53    1         151.203448  107.017396  60.693838   123.022257
#
#    diastolic_bp  smoking  diabetes  heart_attack
# 0     91.378780        0         0             0
# 1     64.355040        1         0             0
# 2     64.953147        0         1             0
# 3     73.821382        0         0             0
# 4     81.121946        0         1             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1000 non-null   int64
#  1   sex                1000 non-null   int64
#  2   total_cholesterol  1000 non-null   float64
#  3   ldl                1000 non-null   float64
#  4   hdl                1000 non-null   float64
#  5   systolic_bp        1000 non-null   float64
#  6   diastolic_bp       1000 non-null   float64
#  7   smoking            1000 non-null   int64
#  8   diabetes           1000 non-null   int64
#  9   heart_attack       1000 non-null   int64
# dtypes: float64(5), int64(5)
# memory usage: 78.3 KB

# %%
df.describe()
# Out:
#                age         sex  total_cholesterol          ldl          hdl  \
# count  1000.000000  1000.00000        1000.000000  1000.000000  1000.000000
# mean     49.886000     0.52700         201.087486   130.047807    49.811244
# std      14.209466     0.49952          40.042655    30.041659    10.247178
# min      18.000000     0.00000          84.165932    36.259745    20.600644
# 25%      40.000000     0.00000         174.707208   111.963197    42.622102
# 50%      49.000000     1.00000         201.191547   130.678540    49.682809
# 75%      59.000000     1.00000         226.251708   149.732446    56.703598
# max      94.000000     1.00000         354.660015   231.376631    82.319810
#
#        systolic_bp  diastolic_bp      smoking     diabetes  heart_attack
# count  1000.000000   1000.000000  1000.000000  1000.000000   1000.000000
# mean    120.312687     80.231248     0.202000     0.090000      0.104000
# ...

# %%
df.value_counts()
# Out:
# age  sex  total_cholesterol  ldl         hdl        systolic_bp  diastolic_bp  smoking  diabetes  heart_attack
# 18   0    128.448722         40.409270   45.445452  105.596508   76.331173     1        0         0               1
# 56   1    247.651385         158.512717  44.676281  120.758152   84.060930     0        0         0               1
#      0    204.979636         93.143978   62.478850  118.838427   80.826287     1        0         0               1
#           209.786867         130.813352  43.008974  120.933763   74.331155     1        0         0               1
#           218.194387         149.978706  33.371654  121.837759   84.497140     0        0         0               1
#                                                                                                                  ..
# 43   1    190.388503         152.809451  35.115620  98.100127    78.037456     0        0         0               1
# ...

# %%
df.mean(), df.median(), df.std()
# Out:
# (age                   49.886000
#  sex                    0.527000
#  total_cholesterol    201.087486
#  ldl                  130.047807
#  hdl                   49.811244
#  systolic_bp          120.312687
#  diastolic_bp          80.231248
#  smoking                0.202000
#  diabetes               0.090000
#  heart_attack           0.104000
#  dtype: float64,
#  age                   49.000000
#  sex                    1.000000
#  total_cholesterol    201.191547
#  ldl                  130.678540
#  hdl                   49.682809
#  systolic_bp          120.042175
#  diastolic_bp          79.912592
#  smoking                0.000000
#  diabetes               0.000000
#  heart_attack           0.000000
#  dtype: float64,
#  age                  14.209466
#  sex                   0.499520
#  total_cholesterol    40.042655
#  ldl                  30.041659
#  hdl                  10.247178
#  systolic_bp          15.507493
#  diastolic_bp         10.235917
# ...

# %%
df.corr()
# Out:
#                         age       sex  total_cholesterol       ldl       hdl  \
# age                1.000000 -0.080798           0.138313  0.276389 -0.130578
# sex               -0.080798  1.000000           0.004318 -0.005930  0.027908
# total_cholesterol  0.138313  0.004318           1.000000  0.792761 -0.476970
# ldl                0.276389 -0.005930           0.792761  1.000000 -0.581038
# hdl               -0.130578  0.027908          -0.476970 -0.581038  1.000000
# systolic_bp        0.342242  0.082735           0.192732  0.289082 -0.064594
# diastolic_bp       0.244088  0.043344           0.095766  0.212360 -0.081822
# smoking           -0.155551  0.067577          -0.056809 -0.135412  0.077156
# diabetes          -0.093922  0.045982          -0.028636 -0.032754  0.016900
# heart_attack       0.109068  0.112803           0.176904  0.158965 -0.145338
#
#                    systolic_bp  diastolic_bp   smoking  diabetes  heart_attack
# ...

# %% [markdown]
# #DATA PREPARATION

# %% [markdown]
# MISSING VALUE

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# age                  0.0
# sex                  0.0
# total_cholesterol    0.0
# ldl                  0.0
# hdl                  0.0
# systolic_bp          0.0
# diastolic_bp         0.0
# smoking              0.0
# diabetes             0.0
# heart_attack         0.0
# dtype: float64

# %%
df[df['hdl'].isnull()]
# Out:
# Empty DataFrame
# Columns: [age, sex, total_cholesterol, ldl, hdl, systolic_bp, diastolic_bp, smoking, diabetes, heart_attack]
# Index: []

# %% [markdown]
# DUPLIKAT

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, sex, total_cholesterol, ldl, hdl, systolic_bp, diastolic_bp, smoking, diabetes, heart_attack]
# Index: []

# %%
df = df.drop_duplicates()

# %% [markdown]
# OUTLIER

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom              Persentase Outliers
# age                                0.4
# total_cholesterol                  1.0
# ldl                                1.2
# hdl                                0.8
# systolic_bp                        0.6
# diastolic_bp                       0.9
# heart_attack                      10.4
# Rasio_Lemak_Darah                  3.7

# %%
CEK nilai yang tidak konsisten (Inconsistent Values)

# %%
df
# Out:
#      age  sex  total_cholesterol         ldl        hdl  systolic_bp  \
# 0     57    1         229.463642  175.879129  39.225687   124.070127
# 1     58    1         186.464120  128.984916  34.950968    95.492552
# 2     37    1         251.300719  152.347592  45.913288    99.519335
# 3     55    1         192.058908  116.803684  67.208925   122.460002
# 4     53    1         151.203448  107.017396  60.693838   123.022257
# ..   ...  ...                ...         ...        ...          ...
# 995   65    1         195.336429  149.070951  43.914928   132.878440
# 996   60    1         192.342928  134.357395  53.380714   145.149535
# 997   70    0         174.179319  125.900047  50.406918   133.022878
# 998   48    0         189.715685  152.388737  40.700912   113.527965
# 999   63    1         136.207724   96.768635  57.566116   136.439507
#
#      diastolic_bp  smoking  diabetes  heart_attack
# 0       91.378780        0         0             0
# ...

# %% [markdown]
# Construct Data

# %%
df["Rasio_Lemak_Darah"] = df["total_cholesterol"] / df["ldl"]


print(df.head())
# Out:
#    age  sex  total_cholesterol         ldl        hdl  systolic_bp  \
# 0   57    1         229.463642  175.879129  39.225687   124.070127
# 1   58    1         186.464120  128.984916  34.950968    95.492552
# 2   37    1         251.300719  152.347592  45.913288    99.519335
# 3   55    1         192.058908  116.803684  67.208925   122.460002
# 4   53    1         151.203448  107.017396  60.693838   123.022257
#
#    diastolic_bp  smoking  diabetes  heart_attack  Rasio_Lemak_Darah
# 0     91.378780        0         0             0           1.304667
# 1     64.355040        1         0             0           1.445627
# 2     64.953147        0         1             0           1.649522
# 3     73.821382        0         0             0           1.644288
# 4     81.121946        0         1             0           1.412887

# %%
df
# Out:
#      age  sex  total_cholesterol         ldl        hdl  systolic_bp  \
# 0     57    1         229.463642  175.879129  39.225687   124.070127
# 1     58    1         186.464120  128.984916  34.950968    95.492552
# 2     37    1         251.300719  152.347592  45.913288    99.519335
# 3     55    1         192.058908  116.803684  67.208925   122.460002
# 4     53    1         151.203448  107.017396  60.693838   123.022257
# ..   ...  ...                ...         ...        ...          ...
# 995   65    1         195.336429  149.070951  43.914928   132.878440
# 996   60    1         192.342928  134.357395  53.380714   145.149535
# 997   70    0         174.179319  125.900047  50.406918   133.022878
# 998   48    0         189.715685  152.388737  40.700912   113.527965
# 999   63    1         136.207724   96.768635  57.566116   136.439507
#
#      diastolic_bp  smoking  diabetes  heart_attack  Rasio_Lemak_Darah
# ...

# %% [markdown]
# Data Reduction

# %%
df = df.drop(columns=["Rasio_Lemak_Darah"])
print(df.head())
# Out:
#    age  total_cholesterol         ldl        hdl  systolic_bp  diastolic_bp  \
# 0   57         229.463642  175.879129  39.225687   124.070127     91.378780
# 1   58         186.464120  128.984916  34.950968    95.492552     64.355040
# 2   37         251.300719  152.347592  45.913288    99.519335     64.953147
# 3   55         192.058908  116.803684  67.208925   122.460002     73.821382
# 4   53         151.203448  107.017396  60.693838   123.022257     81.121946
#
#    heart_attack
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df
# Out:
#      age  total_cholesterol         ldl        hdl  systolic_bp  diastolic_bp  \
# 0     57         229.463642  175.879129  39.225687   124.070127     91.378780
# 1     58         186.464120  128.984916  34.950968    95.492552     64.355040
# 2     37         251.300719  152.347592  45.913288    99.519335     64.953147
# 3     55         192.058908  116.803684  67.208925   122.460002     73.821382
# 4     53         151.203448  107.017396  60.693838   123.022257     81.121946
# ..   ...                ...         ...        ...          ...           ...
# 995   65         195.336429  149.070951  43.914928   132.878440     86.246414
# 996   60         192.342928  134.357395  53.380714   145.149535     91.069141
# 997   70         174.179319  125.900047  50.406918   133.022878     85.851330
# 998   48         189.715685  152.388737  40.700912   113.527965     86.368294
# 999   63         136.207724   96.768635  57.566116   136.439507     98.995934
#
# ...
